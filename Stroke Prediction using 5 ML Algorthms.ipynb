# %%
# %pip install matplotlib
# %pip install seaborn
# %pip install scikit-learn
# Out:
# ...
#
# ...
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: scikit-learn in c:\users\abhishek\appdata\local\programs\python\python311\lib\site-packages (1.4.1.post1)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.rcParams['figure.figsize'] = (8, 8)

# %%
data=pd.read_csv(r'D:\PROJECT\pro\dataset\healthcare-dataset-stroke-data.csv')

# %%
data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %% [markdown]
# # data analysis

# %%
data.shape
# Out:
# (5110, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
data.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# # filling Null Values

# %%
data['bmi'].value_counts()
# Out:
# bmi
# 28.7    41
# 28.4    38
# 26.7    37
# 27.6    37
# 26.1    37
#         ..
# 48.7     1
# 49.2     1
# 51.0     1
# 49.4     1
# 14.9     1
# Name: count, Length: 418, dtype: int64

# %%
data['bmi'].describe()
# Out:
# count    4909.000000
# mean       28.893237
# std         7.854067
# min        10.300000
# 25%        23.500000
# 50%        28.100000
# 75%        33.100000
# max        97.600000
# Name: bmi, dtype: float64

# %%
data['bmi'].fillna(data['bmi'].mean(),inplace=True)

# %%
data['bmi'].describe()
# Out:
# count    5110.000000
# mean       28.893237
# std         7.698018
# min        10.300000
# 25%        23.800000
# 50%        28.400000
# 75%        32.800000
# max        97.600000
# Name: bmi, dtype: float64

# %%
data.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
data.drop('id',axis=1,inplace=True)

# %%
data
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %% [markdown]
# # Label Encoding

# %%
data.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level        bmi   smoking_status  stroke
# 0          Urban             228.69  36.600000  formerly smoked       1
# 1          Rural             202.21  28.893237     never smoked       1
# 2          Rural             105.92  32.500000     never smoked       1
# 3          Urban             171.23  34.400000           smokes       1
# 4          Rural             174.12  24.000000     never smoked       1

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()

# %%
gender=enc.fit_transform(data['gender'])

# %%
smoking_status=enc.fit_transform(data['smoking_status'])

# %%
work_type=enc.fit_transform(data['work_type'])
Residence_type=enc.fit_transform(data['Residence_type'])
ever_married=enc.fit_transform(data['ever_married'])

# %%
data['work_type']=work_type

# %%
data['ever_married']=ever_married
data['Residence_type']=Residence_type
data['smoking_status']=smoking_status
data['gender']=gender

# %%
data
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#       Residence_type  avg_glucose_level        bmi  smoking_status  stroke
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             5110 non-null   int32
#  1   age                5110 non-null   float64
#  2   hypertension       5110 non-null   int64
#  3   heart_disease      5110 non-null   int64
#  4   ever_married       5110 non-null   int32
#  5   work_type          5110 non-null   int32
#  6   Residence_type     5110 non-null   int32
#  7   avg_glucose_level  5110 non-null   float64
#  8   bmi                5110 non-null   float64
#  9   smoking_status     5110 non-null   int32
#  10  stroke             5110 non-null   int64
# dtypes: float64(3), int32(5), int64(3)
# memory usage: 339.5 KB

# %% [markdown]
# # Splitting the data for train and test

# %% [markdown]
# X ---train_X,test_X  80/20
# Y ---train_Y,test_Y

# %%
X=data.drop('stroke',axis=1)

# %%
X.head()
# Out:
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0       1  67.0             0              1             1          2
# 1       0  61.0             0              0             1          3
# 2       1  80.0             0              1             1          2
# 3       0  49.0             0              0             1          2
# 4       0  79.0             1              0             1          3
#
#    Residence_type  avg_glucose_level        bmi  smoking_status
# 0               1             228.69  36.600000               1
# 1               0             202.21  28.893237               2
# 2               0             105.92  32.500000               2
# 3               1             171.23  34.400000               3
# 4               0             174.12  24.000000               2

# %%
Y=data['stroke']

# %%
Y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5105    0
# 5106    0
# 5107    0
# 5108    0
# 5109    0
# Name: stroke, Length: 5110, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
X_train
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 2285       1  49.0             0              0             1          2
# 4733       1  67.0             0              0             1          2
# 3905       1  78.0             0              0             1          2
# 4700       1  47.0             0              0             1          2
# 4939       0  59.0             0              0             1          2
# ...      ...   ...           ...            ...           ...        ...
# 1180       0  62.0             0              0             1          2
# 3441       0  59.0             0              0             1          3
# 1344       1  47.0             0              0             1          2
# 4623       1  25.0             0              0             1          0
# 1289       0  80.0             0              0             1          3
#
#       Residence_type  avg_glucose_level        bmi  smoking_status
# ...

# %%
Y_train
# Out:
# 2285    0
# 4733    0
# 3905    0
# 4700    0
# 4939    0
#        ..
# 1180    0
# 3441    0
# 1344    0
# 4623    0
# 1289    0
# Name: stroke, Length: 4088, dtype: int64

# %%
X_test
# Out:
#       gender    age  hypertension  heart_disease  ever_married  work_type  \
# 2413       0  58.00             0              0             1          2
# 1141       1  57.00             0              0             1          2
# 146        1  65.00             0              0             1          3
# 3883       0   1.64             0              0             0          4
# 1044       0  79.00             0              0             1          0
# ...      ...    ...           ...            ...           ...        ...
# 2261       1  59.00             0              0             1          2
# 4712       1  57.00             0              0             1          2
# 4971       0  63.00             0              0             1          2
# 2224       1  57.00             0              0             1          2
# 4825       0  14.00             0              0             0          4
#
#       Residence_type  avg_glucose_level        bmi  smoking_status
# ...

# %%
Y_test
# Out:
# 2413    0
# 1141    0
# 146     1
# 3883    0
# 1044    0
#        ..
# 2261    0
# 4712    0
# 4971    0
# 2224    0
# 4825    0
# Name: stroke, Length: 1022, dtype: int64

# %% [markdown]
# # Normalize

# %%
data.describe()
# Out:
#             gender          age  hypertension  heart_disease  ever_married  \
# count  5110.000000  5110.000000   5110.000000    5110.000000   5110.000000
# mean      0.414286    43.226614      0.097456       0.054012      0.656164
# std       0.493044    22.612647      0.296607       0.226063      0.475034
# min       0.000000     0.080000      0.000000       0.000000      0.000000
# 25%       0.000000    25.000000      0.000000       0.000000      0.000000
# 50%       0.000000    45.000000      0.000000       0.000000      1.000000
# 75%       1.000000    61.000000      0.000000       0.000000      1.000000
# max       2.000000    82.000000      1.000000       1.000000      1.000000
#
#          work_type  Residence_type  avg_glucose_level          bmi  \
# count  5110.000000     5110.000000        5110.000000  5110.000000
# mean      2.167710        0.508023         106.147677    28.893237
# std       1.090293        0.499985          45.283560     7.698018
# ...

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()

# %%
X_train_std=std.fit_transform(X_train)
X_test_std=std.transform(X_test)

# %% [markdown]
# # lets save the scaler object

# %%
import pickle
import os

# %%
scaler_path=os.path.join('D:\PROJECT\pro','models/scaler.pkl')
with open(scaler_path,'wb') as scaler_file:
    pickle.dump(std,scaler_file)

# %%
X_train_std
# Out:
# array([[ 1.19359699,  0.2521852 , -0.33069968, ..., -0.58626884,
#          0.00238781,  1.51158251],
#        [ 1.19359699,  1.04686385, -0.33069968, ..., -0.50843521,
#         -0.44065504, -0.35191245],
#        [ 1.19359699,  1.5325008 , -0.33069968, ...,  2.27080023,
#         -0.58427812, -0.35191245],
#        ...,
#        [ 1.19359699,  0.16388757, -0.33069968, ..., -0.43745625,
#          1.34810513,  1.51158251],
#        [ 1.19359699, -0.80738634, -0.33069968, ...,  1.33171097,
#         -0.75401449,  0.57983503],
#        [-0.83780372,  1.62079843, -0.33069968, ..., -0.74171498,
#         -0.16646553,  0.57983503]])

# %%
X_test_std
# Out:
# array([[-0.83780372,  0.64952452, -0.33069968, ..., -0.12678509,
#          1.38727506,  1.51158251],
#        [ 1.19359699,  0.60537571, -0.33069968, ..., -0.35586361,
#          0.12078063, -1.28365994],
#        [ 1.19359699,  0.95856622, -0.33069968, ..., -0.83414241,
#          0.00238781, -0.35191245],
#        ...,
#        [-0.83780372,  0.87026859, -0.33069968, ..., -1.08555387,
#          1.17836876,  0.57983503],
#        [ 1.19359699,  0.60537571, -0.33069968, ..., -0.66056457,
#          0.32968693, -0.35191245],
#        [-0.83780372, -1.29302329, -0.33069968, ..., -0.75962556,
#         -1.31545016, -1.28365994]])

# %% [markdown]
# # Training

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train_std,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.feature_importances_
# Out:
# array([0.0396842 , 0.1767055 , 0.01578856, 0.02057535, 0.02375516,
#        0.05424257, 0.03748411, 0.28691332, 0.27385858, 0.07099263])

# %%
X_train.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status'],
#       dtype='object')

# %%
Y_pred=dt.predict(X_test_std)

# %%
Y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
ac_dt=accuracy_score(Y_test,Y_pred)

# %%
ac_dt
# Out:
# 0.9021526418786693

# %%
from sklearn.metrics import f1_score

f1_dt= f1_score(Y_test, Y_pred, average='weighted')
print("F1 Score:", f1_dt)
# Out:
# F1 Score: 0.8972146929051549

# %%
import joblib
model_path=os.path.join('D:\PROJECT\pro/','models/dt.sav')
joblib.dump(dt,model_path)
# Out:
# ['D:\\PROJECT\\pro/models/dt.sav']

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(max_iter=1000)

# %%
lr.fit(X_train_std,Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
Y_pred_lr=lr.predict(X_test_std)

# %%
from sklearn.metrics import f1_score

f1_lr= f1_score(Y_test, Y_pred, average='weighted')

# Print or store the F1 score
print("F1 Score for Logistic Regression:", f1_lr)
# Out:
# F1 Score for Logistic Regression: 0.8972146929051549

# %%
Y_pred_lr
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
ac_lr=accuracy_score(Y_test,Y_pred_lr)

# %%
ac_lr
# Out:
# 0.9383561643835616

# %%
from sklearn.linear_model import LogisticRegression
import joblib
import os
model_path = os.path.join('D:\PROJECT\pro/', 'models/lr.sav')
joblib.dump(lr, model_path)
# Out:
# ['D:\\PROJECT\\pro/models/lr.sav']

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

# %%
knn.fit(X_train_std,Y_train)
# Out:
# KNeighborsClassifier()

# %%
Y_pred=knn.predict(X_test_std)

# %%
ac_knn=accuracy_score(Y_test,Y_pred)

# %%
ac_knn
# Out:
# 0.9344422700587084

# %%
from sklearn.metrics import f1_score

f1_knn= f1_score(Y_test, Y_pred, average='weighted')
print("F1 Score:", f1_knn)
# Out:
# F1 Score: 0.9075008389037532

# %%
import joblib
import os
model_path = os.path.join('D:\PROJECT\pro/', 'models/knn.sav')
joblib.dump(knn, model_path)
# Out:
# ['D:\\PROJECT\\pro/models/knn.sav']

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(X_train_std,Y_train)
# Out:
# RandomForestClassifier()

# %%
Y_pred=rf.predict(X_test_std)

# %%
ac_rf=accuracy_score(Y_test,Y_pred)

# %%
ac_rf
# Out:
# 0.9373776908023483

# %%
ac_knn
# Out:
# 0.9344422700587084

# %%
ac_dt
# Out:
# 0.9021526418786693

# %%
ac_lr
# Out:
# 0.9383561643835616

# %%
from sklearn.metrics import f1_score

f1_rf= f1_score(Y_test, Y_pred, average='weighted')
print("F1 Score:", f1_rf)
# Out:
# F1 Score: 0.9089723062325802

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

# %%
sv=SVC(probability=True)

# %%
sv.fit(X_train_std,Y_train)
# Out:
# SVC(probability=True)

# %%
Y_pred=sv.predict(X_test_std)

# %%
ac_sv=accuracy_score(Y_test,Y_pred)

# %%
ac_sv
# Out:
# 0.9393346379647749

# %%
ac_lr
# Out:
# 0.9383561643835616

# %%
from sklearn.metrics import f1_score

f1_sv= f1_score(Y_test, Y_pred, average='weighted')
print("F1 Score:", f1_sv)
# Out:
# F1 Score: 0.9099508097337881

# %%
import joblib
import os
model_path = os.path.join('D:\PROJECT\pro/', 'models/sv.sav')
joblib.dump(sv, model_path)
# Out:
# ['D:\\PROJECT\\pro/models/sv.sav']

# %%
import joblib


dt_model = joblib.load('D:\PROJECT\pro\models/dt.sav')


svm_model = joblib.load('D:\PROJECT\pro\models/sv.sav')


knn_model = joblib.load('D:\PROJECT\pro\models/knn.sav')

lr_model = joblib.load('D:\PROJECT\pro\models/lr.sav')


from sklearn.ensemble import VotingClassifier
voting_clf = VotingClassifier(estimators=[
    ('dt', dt_model), ('svm', svm_model), ('knn', knn_model),('lr', lr_model)], voting='soft')
voting_clf.fit(X_train, Y_train)

y_pred = voting_clf.predict(X_test)
ac_ens=accuracy_score(Y_test,Y_pred)
from sklearn.metrics import f1_score

f1_ens= f1_score(Y_test, Y_pred, average='weighted')
print("F1 Score:", f1_ens)

joblib.dump(voting_clf, 'D:\PROJECT\pro\models/ens.sav')
# Out:
# F1 Score: 0.9099508097337881
# ['D:\\PROJECT\\pro\\models/ens.sav']

# %%
ac_ens
# Out:
# 0.9393346379647749

# %%
plt.bar(['Decision Tree','Logistic','KNN','SVM','Random Forest','ENSEMBLED'],[ac_dt,ac_lr,ac_knn,ac_sv,ac_rf,ac_ens])
plt.xlabel("Algorithms")
plt.ylabel("Accuracy")
plt.show()

# %%
plt.bar(['Decision Tree','Logistic','KNN','SVM','Random Forest','ENSEMBLED'],[f1_dt,f1_lr,f1_knn,f1_sv,f1_rf,f1_ens])
plt.xlabel("Algorithms")
plt.ylabel("F1 SCORE")
plt.show()
print("F1 score of Decission tree:",f1_dt)
print("F1 score of KNN:",f1_knn)
print("F1 score of SVM:",f1_sv)
print("F1 score of Logiatic Regression:",f1_lr)
print("F1 score of Ensembled:",f1_ens)
# Out:
# F1 score of Decission tree: 0.8972146929051549
# F1 score of KNN: 0.9075008389037532
# F1 score of SVM: 0.9099508097337881
# F1 score of Logiatic Regression: 0.8972146929051549
# F1 score of Ensembled: 0.9099508097337881
